# %%
from gensim.utils import tokenize
import pandas as pd
import numpy as np
import sys
import os
from lexicalrichness import LexicalRichness
import lmppl
scorer = lmppl.MaskedLM('distilbert-base-uncased')

# %%
window_size = 5
def mtld(text):
    lex = LexicalRichness(text)
    return lex.mtld()

def mattr(text):
    lex = LexicalRichness(text)
    return lex.mattr(window_size)

def hdd(text):
    lex = LexicalRichness(text)
    return lex.hdd(window_size)

# %%
from transformers import GPT2LMHeadModel, GPT2TokenizerFast
import torch

model_id = "gpt2"
model = GPT2LMHeadModel.from_pretrained(model_id)
tokenizer = GPT2TokenizerFast.from_pretrained(model_id)
def ppl(text):
    max_length = model.config.n_positions
    stride = 512
    encodings = tokenizer(text, return_tensors="pt")
    seq_len = encodings.input_ids.size(1)

    nlls = []
    prev_end_loc = 0
    for begin_loc in range(0, seq_len, stride):
        end_loc = min(begin_loc + max_length, seq_len)
        trg_len = end_loc - prev_end_loc  # may be different from stride on last loop
        input_ids = encodings.input_ids[:, begin_loc:end_loc]
        target_ids = input_ids.clone()
        target_ids[:, :-trg_len] = -100

        with torch.no_grad():
            outputs = model(input_ids, labels=target_ids)

            # loss is calculated using CrossEntropyLoss which averages over valid labels
            # N.B. the model only calculates loss over trg_len - 1 labels, because it internally shifts the labels
            # to the left by 1.
            neg_log_likelihood = outputs.loss

        nlls.append(neg_log_likelihood)

        prev_end_loc = end_loc
        if end_loc == seq_len:
            break

    ppl = torch.exp(torch.stack(nlls).mean())
    
    return ppl.item()

# %%
df = pd.read_csv("/Users/Lara/Dropbox/LanguageGender/Data/Advocates/Cleaned/cleaned_Advocates_Full_Apr13.csv")
df = df.drop(columns=['Unnamed: 0'])
coded = pd.read_csv("~/Documents/Stanford/Research/Culture_Survey/Data/Coded_Apr13_Devon_Apr21.csv")

# %%
coded = coded.rename(columns={'coding (1 = relevant to accountabiliy, 0 = irrelevant to accountability)':'relevance'})

# %%
df = pd.merge(df, coded[['ResponseId', 'relevance']], on=['ResponseId'])

# %%
df['text_length'] = df['text'].apply(lambda s : len(list(tokenize(s))))
df = df.loc[df['relevance']==1]
df = df.loc[df['text_length'] >= window_size]

# %%
df.sort_values('text_length')
# Out:
#             ResponseId                                   Intro.Question.1  \
# 733  R_0ian77UBWVwno89  accountability means taking responsibility for...
# 190  R_x2Qd2x0JxjvZDmF  Accountability means that the customer can hol...
# 361  R_1psago8ffhvqEU9  it means to keep your word as your honor and t...
# 106  R_ZjIHQjKWLdx0rst         Having to answer for the choices you make.
# 694  R_31ynQWpZKubrO2S             taking responsibility for ones actions
# ..                 ...                                                ...
# 607  R_1joH3CG8BGMdWdC  Accountability is being responsible for your o...
# 567  R_2pYmw1Ge1TjUfIV        taking responsibility for one's own actions
# 378  R_2fq6H6azf0ACzex  Accountability means admitting when you're in ...
# 530  R_3MAnlveCqhco3o4  Accountability refers to the willingness and a...
# 334  R_ukQ7Dy5uFRgDt6N  Being accountable means owning up to one's mis...
#
#                                       Intro.Question.2  \
# 733                        apologizing without excuses
# 190  An example could be missing a deadline on a pr...
# 361  when you accidentally delete a bunch of softwa...
# 106  Someone sends an email that causes confusion a...
# 694                  admitting a mistake that you made
# ..                                                 ...
# 607  If somebody does poorly on a high school test ...
# 567  Let's say an employee has been assigned a proj...
# 378  Admitting that you were wrong after fighting w...
# 530  One example would be an employee taking owners...
# 334  Suppose a team member misses a deadline on a p...
#
#                                         Education  Age  Gender Gender_3_TEXT  \
# 733                                  Some college   27  Female           NaN
# 190                                  Some college   30    Male           NaN
# 361                               Bachelor degree   27  Female           NaN
# 106                               Graduate degree   41    Male           NaN
# 694                                  Some college   47  Female           NaN
# ..                                            ...  ...     ...           ...
# 607  High school degree of equivalent (e.g., GED)   46    Male           NaN
# 567                                  Some college   44  Female           NaN
# 378                                  Some college   31    Male           NaN
# 530                               Bachelor degree   43    Male           NaN
# 334                               Bachelor degree   24    Male           NaN
#
#     Attention.Check                            Ethnicity Ethnicity_6_TEXT  \
# 733          Purple  Latino or Latina,White or Caucasian              NaN
# 190          Purple                   White or Caucasian              NaN
# 361          Purple              Asian or Asian American              NaN
# 106          Purple                   White or Caucasian              NaN
# 694          Purple                   White or Caucasian              NaN
# ..              ...                                  ...              ...
# 607          Purple                   White or Caucasian              NaN
# 567          Purple              Asian or Asian American              NaN
# 378          Purple                   White or Caucasian              NaN
# 530          Purple            Black of African American              NaN
# 334          Purple                   White or Caucasian              NaN
#
#      ...  NeedChange Prior.Experience    Advocate           Implementation  \
# 733  ...  Moderately               No         NaN                      NaN
# 190  ...  Not at all              Yes  Moderately  Extremely\nProfessional
# 361  ...    Slightly               No         NaN                      NaN
# 106  ...  Moderately              Yes  Not at all                  Neutral
# 694  ...    Slightly              Yes   Extremely  Extremely\nProfessional
# ..   ...         ...              ...         ...                      ...
# 607  ...  Not at all               No         NaN                      NaN
# 567  ...    Slightly              Yes    Somewhat  Somewhat Unprofessional
# 378  ...    Slightly              Yes   Extremely    Somewhat Professional
# 530  ...  Moderately               No         NaN                      NaN
# 334  ...    Slightly               No         NaN                      NaN
#
#                  Outcome                                           Comments  \
# 733                  NaN                                                 no
# 190  Extremely\nPositive                                                NaN
# 361                  NaN                                                NaN
# 106              Neutral                                                NaN
# 694  Extremely\nPositive                                                 no
# ..                   ...                                                ...
# 607                  NaN  Farm and Ranch labor, I selected the option th...
# 567   Somewhat\nPositive                                                 no
# 378  Extremely\nPositive                                                 No
# 530                  NaN                                                NaN
# 334                  NaN                                    Nope, all good.
#
#                                                   text    treatment relevance  \
# 733                    take pride in being accountable  Treatment 2         1
# 190                  Get your credit! Be accountable!   Treatment 2         1
# 361              always be responsible and accountable  Treatment 2         1
# 106       Accountability is everyone's responsibility.  Treatment 2         1
# 694                     Accountability goes a long way  Treatment 2         1
# ..                                                 ...          ...       ...
# 607  If you work hard and do good things as far as ...  Treatment 3         1
# 567  Sure, as an informal advocate for the adoption...  Treatment 1         1
# 378  AT Metrics is introducing a new core value to ...      Control         1
# 530  Hello colleagues, I would like to talk to you ...  Treatment 3         1
# 334  accountability means taking responsibility for...  Treatment 3         1
#
#     text_length
# 733           5
# 190           5
# 361           5
# 106           5
# 694           5
# ..          ...
# 607         117
# 567         126
# 378         159
# 530         161
# 334         163
#
# [754 rows x 27 columns]

# %%
df['mtld'] = df['text'].apply(mtld)
df['mattr'] = df['text'].apply(mattr)
df['hdd'] = df['text'].apply(hdd)

# %%
df['perplexity'] = df['text'].apply(ppl)

# %%
df.to_csv("/Users/Lara/Dropbox/LanguageGender/Data/Advocates/Cleaned/responses_linguistic_measures.csv", index=False)
